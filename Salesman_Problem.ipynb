# %% [markdown]
# ## Recuit simulé pour le problème du voyageur de commerce

# %% [markdown]
# CSI4506 Intelligence Artificielle
# Automne 2020
# Caroline Barrière, Julian Templeton et Justin Charbonneau

# %% [markdown]
# Ce devoir vous permettra de mieux comprendre les algorithmes de recherche aléatoire vus en classe, en particulier l'algorithme de *recuit simulé*, qui est une méthode connue qui exemplifie bien la *modification aléatoire*.  Au départ, une solution gloutonne est proposée.  Cette solution est révisée petit à petit pour arriver à une meilleure solution.
#
# Le domaine d'application utilisé ici pour expérimenter avec le *recuit simulé* est le problème du voyageur de commerce (Traveling salesman problem).  C'est un problème classique, dans lequel le but est de visiter toutes les villes d'un graphe interconnecté de villes, et ce, en parcourant la plus petite distance possible.
#
# Ce notebook va dabord explorer la __méthode gloutonne__ puis la __méthode gloutonne aléatoire__ pour enfin aboutir au __recuit simulé__.

# %% [markdown]
# ***DEVOIR***:
# Parcourir le notebook, en exécutant chaque cellule, une à une.
# Pour chaque **(TO DO)**, effectuer les tâches demandées.
# Quand vous avez terminé, signez (voir cette étape ajoutée à la fin) et soumettez votre notebook.
#
# Ce notebook sera évalué sur 20 points.
# Chaque **(TO DO)** aura un pointage associé.
# ***

# %% [markdown]
# **1. Nous définissons d'abord un petit nombre de villes**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# La méthode *showNodes* ci-bas nous permet de visualiser la position des villes.
#
# Les packages **matplotlib** , **networkx** et **numpy** doivent d'abord être installés.
#
# Pour faire l'installation des packages, ouvrir une invite de commande, et tapez **pip install networkx** ainsi que **pip install numpy** (Si vous avez linux ou un Mac, vous pouvez utiliser **pip3** au lieu de **pip** selon la configuration de votre environnement). Matplotlib devrait déjà être installé mais si ce n'est pas le cas, utilisez la commande **pip install matplotlib** pour l'installer.
#
# Vous pouvez également profiter des commandes magiques et insérer une cellule de code et inscrire **%pip install networkx**.  Une fois les packages installés, vous devrez probablement redémarrer le *kernel*.  Ensuite, vous serez en mesure d'exécuter la cellule ci-bas.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Mesurons les distances entre les villes
# D'abord, nous définissons une méthode pour calculer la distance entre deux villes spécifiques.  Ensuite nous définissons une méthode pour trouver l'ensemble des distances entre plusieurs paires de noeuds (villes).

# %%
import math

def dist(node1, node2):
    """
    Returns the euclidian distance between two nodes
    """
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
def distDict(nodes):
    """Building a dictionary of all pairs or distances"""
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %% [markdown]
# Ajoutons aussi une méthode pour trouver la ville la plus proche d'une autre ville.  Cette méthode sera utile plus tard.

# %%
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    """
    Find the min distance from node1 to all other nodes.
    It receives the node1 label, the labels of other nodes to test, and the precalculated distances between all nodes
    """
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Solution gloutonne d'abord
# Avant de pouvoir utiliser le *recuit simulé*, il faut une première solution sous-optimale.  Nous utilisons un algorithme glouton pour générer cette solution. D'abord, le choix du noeud initiale sera aléatoire, puis par après l'algorithme choisira toujours le noeud le plus près.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['E', 'A', 'C', 'B', 'D']

# %% [markdown]
# #### 4. Visualisation d'un chemin dans le graphe
# Nous modifions légèrement la méthode *showNodes* vue précédemment pour devenir *showPath* et montrer un chemin dans un graphe dirigé.

# %%
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    """
    Small method to show a path
    It receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E'] and a dictionary of all the nodes and their positions
    """
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 points**
# 1. Sélectionner un seed (numéro entier) à spécifier ci-bas pour rendre votre code reproductible.
# 2. Exécuter la cellule pour initialiser le générateur de nombres pseudo-aléatoires avec un numéro d'initialisation (**une fois seulement**)
# 3. Exécuter les test en-dessous de la déclaration du générateur de nombre plusieurs fois (manuellement exécuter la cellule) jusqu'à l'optention de deux solutions identiques. Enregistrer le nombre de fois que vous avez exécuter la cellule dans la section réponse ainsi que les deux chemins pour les deux solutions dans la section réponse.
# 4. Exécuter les test en-dessous de la déclaration du générateur de nombre plusieurs fois encore jusqu'à l'obtention de résultats différents pour les deux solutions. Enregistrer le nombre de fois que vous avez exécuter la cellule ainsi que les deux différents chemins pour les deux solutions dans la section réponse.

# %% [markdown]
# **(Présentez vos réponses dans ce Markdown)**
# Nb d'exécutions pour générer deux solutions identiques gs1 et gs2 : 2
#
# Chemins des 2 solutions identiques gs1 et gs2 : [D, C, A, B, E]
#
# Nb d'exécutions pour générer deux solutions différentes gs1 et gs2 :  1
#
# Chemins des 2 solutions différentes gs1 et gs2 : [E, A, C, B, D] et [A, C, B, D, E]

# %% [markdown]
# Initialiser le générateur de nombres

# %%
# (TO DO) for reproducibility
random.seed(10) # Enter any integer in the parenthesis to set the seed

# %% [markdown]
# Un test pour visualiser 2 solutions gloutonnes. Regardez la sortie de texte du chemin pour voir si le graphique tracé contient des arêtes qui passent par un nœud.

# %%
# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['E', 'A', 'C', 'B', 'D']
# ['A', 'C', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 points**
# Compléter la méthode ci-bas pour trouver la longueur total d'un chemin.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i+1]
        total += distanceDict[x,y]
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 5.414
# 6.0

# %% [markdown]
# **(TO DO) Q3 - 4 points**
# Ajouter 2 nouvelles villes (positionner les villes où vous voulez dans le graphe prédéfini de -2 à 2).  Donc, refaire la séquence d'étapes ci-haut (1) définir un graphe, (2) visualiser les positions des villes (3) contruire le dictionnaire des distances (4) trouver deux solutions gloutonnes (5) montrer les chemins pour ces solutions.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (0,1), 'G': (0,2)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
# (4) Find two unique greedy solutions 
gs1 = greedy_solution(moreCities)
showPath(gs1, moreCities)
gs2 = greedy_solution(moreCities)
showPath(gs2, moreCities)
# (5) Show the two unique paths found above along with their total distances
print(gs1)
print(gs2)
print(totalDist(gs1, moreDistances))
print(totalDist(gs2, moreDistances))
# Out:
# ['E', 'A', 'C', 'B', 'F', 'G', 'D']
# ['A', 'C', 'B', 'F', 'G', 'D', 'E']
# 8.576
# 9.162

# %% [markdown]
# **5. Gloutonne Aléatoire - Setup**
#
# Avant de créer notre solution gloutonne aléatoire, nous définissons une fonction qui s'appelle kClosestNodes qui retournera les k noeuds les plus près du noeud spécifié.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Gloutonne Aléatoire**
#
# Maintenant vous allez trouver une autre solution sous-optimale. Cette deuxième solution sera la méthode gloutonne aléatoire.

# %% [markdown]
# **(TO DO) Q4 - 5 points**
#
# La méthode gloutonne aléatoire va dabord sélectionner un noeud initial aléatoire. Ensuite, l'algorithme va choisir aléatoirement un noeud parmis k noeuds disponibles en fonction d'une distribution de probabilités (au lieu du noeud le plus près).
#
# Par exemple, si vous observez les 5 noeuds voisins, vous allez choisir un noeud aléatoirement mais chacun des 5 noeuds aura une probabilité plus ou moins grande d'être sélectionné en fonction de sa distance.
#
# Cette distribution de probabilité est définie avec la fonction *normalize* ci-bas. Les k noeuds les plus près seront retournés par la fonction *kClosestNodes* ci-haut. Vous devez appeler ces deux fonctions dans votre solution puis suivre les instructions défini par les commentaires.
#
# Après avoir terminé, ajouter un autre test aux tests ci-bas avec des différentes valeurs de k.

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION #
def normalize(nodeFrom, nodesTo, distDict):
    """
    nodeFrom is the node we start at, nodesTo is a list of nodes
    that nodeFrom can go to, and distDict is the dictionary of all
    combinations of distances. This provides the probability distribution to be used by
    randomized_greedy_solution
    """
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# TO DO #
def randomized_greedy_solution(nodes, k):
    """
    k represents the number of closest nodes to be returned from the
    function kClosestNodes
    """
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        kClosest = kClosestNodes(cur_node, free_list, allDist, k)
        
        
        # Find the normalized distances
        normalizedDistances = normalize(cur_node, kClosest, allDist)
        print("normalized distances: " + str(normalizedDistances))
        
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        # ...
        found_node = np.random.choice(kClosest, p=normalizedDistances)
        
        
        
        
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        
        print("closest nodes:" + str(kClosest))
        print("normalized distances: " + str(normalizedDistances))
        
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        
        print("found node: " + str(found_node))

        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)

# TO DO: Add one more test randomized_greedy_solution with a different k
# ...
# Out:
# Greedy Test
# ['B', 'C', 'A', 'F', 'G', 'D', 'E']
# 9.162
# Randomized Greedy Test
# normalized distances: [1.0]
# closest nodes:['C']
# normalized distances: [1.0]
# found node: C
# normalized distances: [1.0]
# closest nodes:['A']
# normalized distances: [1.0]
# found node: A
# normalized distances: [1.0]
# closest nodes:['F']
# normalized distances: [1.0]
# found node: F
# normalized distances: [1.0]
# closest nodes:['B']
# normalized distances: [1.0]
# found node: B
# normalized distances: [1.0]
# closest nodes:['G']
# normalized distances: [1.0]
# found node: G
# normalized distances: [1.0]
# closest nodes:['E']
# normalized distances: [1.0]
# found node: E
# ['D', 'C', 'A', 'F', 'B', 'G', 'E']
# 8.576
# Randomized Greedy Test
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# closest nodes:['F', 'B']
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# found node: B
# normalized distances: [0.5, 0.5]
# closest nodes:['C', 'F']
# normalized distances: [0.5, 0.5]
# found node: F
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# closest nodes:['A', 'C']
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# found node: A
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# closest nodes:['C', 'D']
# normalized distances: [0.6665995420411309, 0.3334004579588691]
# found node: C
# normalized distances: [0.8333248884610154, 0.1666751115389846]
# closest nodes:['D', 'E']
# normalized distances: [0.8333248884610154, 0.1666751115389846]
# found node: D
# normalized distances: [1.0]
# closest nodes:['E']
# normalized distances: [1.0]
# found node: E
# ['G', 'B', 'F', 'A', 'C', 'D', 'E']
# 7.414

# %% [markdown]
# **7. Definissons le processus du recuit simulé**
# La classe ci-bas définit le processus du recuit simulé.  Cette classe est une adaptation de la classe *anneal.py* qui se trouve dans le code python du github https://github.com/chncyhn/simulated-annealing-tsp. Vous n'avez pas à modifier cette classe, mais tenter de la comprendre pour assimiler l'algorithme du recuit simulé.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refinement d'une solution gloutonne avec recuit simulé

# %% [markdown]
# **(TO DO) Q5 - 5 points**
# Ajoutez des commentaires au code ci-bas pour expliquer ce qui se passe.  Aussi exécuter le code quelques fois.  Cela vous montrera qu'il peut y avoir parfois un coût total plus bas en appliquant le recuit simulé.

# %%
#Appeler la fonction d'algorithme glouton pour la variable manyCities
firstSol = greedy_solution(moreCities) 
distances = distDict(moreCities) # Construire le dictionnaire de distances
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances))) # Imprimer le cout de la solution
showPath(firstSol, moreCities) # Imprimer le graphe

#Appeler la classe de recuit simulé, avec comme attributs moreCities, et False, car on travaille ici avec l'algorithme glouton
sa = SimAnneal(moreCities, False) # L'attribut est faux, car on veut une meilleure solution pour l'algorithme glouton
betterSol = sa.anneal() # On génère une meilleure solution
showPath(betterSol, moreCities) # Imprimer le graphe

# Appeler la fonction d'algorithme glouton aléatoire 
secondSol = randomized_greedy_solution(moreCities, 4) # Nombre 4 est le nombre de noeuds proches à retourner
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances))) # Imprimer le cout de la solution
showPath(secondSol, moreCities) # Imprimer le graphe

#Appeler la classe de recuit simulé, avec comme attributs moreCities, et True, car on travaille ici avec l'algorithme glouton aléatoire
sa2 = SimAnneal(moreCities, True, 4) 
betterSol2 = sa2.anneal() # Générer une meilleure solution
showPath(betterSol2, moreCities) # Afficher le graphe
# Out:
# Solution ['D', 'C', 'A', 'F', 'B', 'G', 'E'] takes a total of 8.576
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over greedy heuristic:  0.1465
# normalized distances: [0.2857019559920368, 0.2857019559920368, 0.2857019559920368, 0.14289413202388965]
# closest nodes:['A', 'B', 'G', 'C']
# normalized distances: [0.2857019559920368, 0.2857019559920368, 0.2857019559920368, 0.14289413202388965]
# found node: G
# normalized distances: [0.4762523369027656, 0.23805425434851044, 0.19045498314178333, 0.09523842560694075]
# closest nodes:['B', 'A', 'C', 'D']
# normalized distances: [0.4762523369027656, 0.23805425434851044, 0.19045498314178333, 0.09523842560694075]
# found node: B
# normalized distances: [0.5332796336329048, 0.2667203663670953, 0.1333199084082262, 0.06668009159177382]
# closest nodes:['C', 'A', 'D', 'E']
# normalized distances: [0.5332796336329048, 0.2667203663670953, 0.1333199084082262, 0.06668009159177382]
# found node: A
# normalized distances: [0.4999244885977782, 0.25003775570111086, 0.25003775570111086]
# closest nodes:['C', 'D', 'E']
# normalized distances: [0.4999244885977782, 0.25003775570111086, 0.25003775570111086]
# found node: C
# normalized distances: [0.8333248884610154, 0.1666751115389846]
# closest nodes:['D', 'E']
# normalized distances: [0.8333248884610154, 0.1666751115389846]
# found node: D
# normalized distances: [1.0]
# closest nodes:['E']
# normalized distances: [1.0]
# found node: E
# Solution ['F', 'G', 'B', 'A', 'C', 'D', 'E'] takes a total of 7.828
# normalized distances: [0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198]
# closest nodes:['C', 'A', 'B', 'E']
# normalized distances: [0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198]
# found node: C
# normalized distances: [0.3703479840205153, 0.3703479840205153, 0.18522993144955543, 0.07407410050941401]
# closest nodes:['A', 'B', 'F', 'E']
# normalized distances: [0.3703479840205153, 0.3703479840205153, 0.18522993144955543, 0.07407410050941401]
# found node: A
# normalized distances: [0.44438478011310784, 0.2222595124293076, 0.2222595124293076, 0.11109619502827696]
# closest nodes:['F', 'B', 'E', 'G']
# normalized distances: [0.44438478011310784, 0.2222595124293076, 0.2222595124293076, 0.11109619502827696]
# found node: F
# normalized distances: [0.45454294200988565, 0.45454294200988565, 0.09091411598022871]
# closest nodes:['B', 'G', 'E']
# normalized distances: [0.45454294200988565, 0.45454294200988565, 0.09091411598022871]
# found node: B
# normalized distances: [0.8, 0.2]
# closest nodes:['G', 'E']
# normalized distances: [0.8, 0.2]
# found node: G
# normalized distances: [1.0]
# closest nodes:['E']
# normalized distances: [1.0]
# found node: E
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over randomized greedy heuristic:  0.2038

# %% [markdown]
# **9. Test à plus grande échelle**
# Le fichier *coord.txt* (que vous trouverez aussi sur Brightspace dans la section des Jupyter Notebooks), contient un ensemble de coordonnées. Ce fichier de données est aussi tiré du github https://github.com/chncyhn/simulated-annealing-tsp.  Voici le début du fichier.
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Nous utiliserons le chiffre de la première colonne comme étiquette de la ville (e.g. ville 0, ville 1, ...) et les deux autres colonnes comme les coordonnées.
#
# Assurez-vous de mettre le fichier *coord.txt* dans le même répertoire que votre notebook (ou sinon changer le chemin d'accès dans le code ci-bas).

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Visualisons où sont les noeuds pour cet exemple.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Nous pouvons maintenant tester le processus de *recuit simulé* sur ce plus grand exemple.  Le code test est très similaire au code que vous avez commenté à la question (5) ci-haut.  Regarder l'étape supplémentaire, *plot_learning*, qui montre la valeur de la fonction de coût au fur et à mesure de la progression de l'algorithme.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['10', '16', '25', '1', '2', '3', '17', '11', '18', '19', '12', '13', '15', '14', '38', '39', '43', '37', '40', '41', '35', '32', '33', '42', '31', '44', '45', '9', '22', '21', '20', '26', '27', '23', '24', '4', '5', '36', '8', '6', '7', '28', '30', '34', '29'] takes a total of 595.39
# 6.708203932499369
# 1e-08
# Best fitness obtained:  552.889
# Improvement over greedy heuristic:  0.1208
# normalized distances: [0.4689704744281296, 0.3763102690930456, 0.15471925647882473]
# closest nodes:['2', '17', '16']
# normalized distances: [0.4689704744281296, 0.3763102690930456, 0.15471925647882473]
# found node: 2
# normalized distances: [0.5234815770245258, 0.32210653570994496, 0.1544118872655292]
# closest nodes:['16', '10', '25']
# normalized distances: [0.5234815770245258, 0.32210653570994496, 0.1544118872655292]
# found node: 16
# normalized distances: [0.7614105084940352, 0.11959039522652605, 0.11899909627943875]
# closest nodes:['10', '25', '1']
# normalized distances: [0.7614105084940352, 0.11959039522652605, 0.11899909627943875]
# found node: 10
# normalized distances: [0.4801109232601883, 0.47868573392155067, 0.04120334281826117]
# closest nodes:['25', '1', '17']
# normalized distances: [0.4801109232601883, 0.47868573392155067, 0.04120334281826117]
# found node: 1
# normalized distances: [0.9999978359359724, 1.1763517910417939e-06, 9.877122365444486e-07]
# closest nodes:['25', '17', '22']
# normalized distances: [0.9999978359359724, 1.1763517910417939e-06, 9.877122365444486e-07]
# found node: 25
# normalized distances: [0.3794705084036472, 0.31735993433694365, 0.30316955725940914]
# closest nodes:['17', '22', '21']
# normalized distances: [0.3794705084036472, 0.31735993433694365, 0.30316955725940914]
# found node: 22
# normalized distances: [0.9979111344744157, 0.0011076083854185193, 0.0009812571401658075]
# closest nodes:['21', '9', '20']
# normalized distances: [0.9979111344744157, 0.0011076083854185193, 0.0009812571401658075]
# found node: 21
# normalized distances: [0.3767006621382402, 0.3597253461884748, 0.26357399167328494]
# closest nodes:['9', '20', '17']
# normalized distances: [0.3767006621382402, 0.3597253461884748, 0.26357399167328494]
# found node: 9
# normalized distances: [0.4109467725736635, 0.29680860577326074, 0.29224462165307574]
# closest nodes:['20', '45', '44']
# normalized distances: [0.4109467725736635, 0.29680860577326074, 0.29224462165307574]
# found node: 45
# normalized distances: [0.9934851573120822, 0.0032574213439588856, 0.0032574213439588856]
# closest nodes:['44', '31', '43']
# normalized distances: [0.9934851573120822, 0.0032574213439588856, 0.0032574213439588856]
# found node: 44
# normalized distances: [0.35420259907386764, 0.3299255316493405, 0.3158718692767919]
# closest nodes:['43', '31', '42']
# normalized distances: [0.35420259907386764, 0.3299255316493405, 0.3158718692767919]
# found node: 31
# normalized distances: [0.9760825428304646, 0.012012998920428746, 0.011904458249106735]
# closest nodes:['42', '41', '40']
# normalized distances: [0.9760825428304646, 0.012012998920428746, 0.011904458249106735]
# found node: 42
# normalized distances: [0.3933000327058367, 0.38882466987204006, 0.21787529742212336]
# closest nodes:['41', '40', '32']
# normalized distances: [0.3933000327058367, 0.38882466987204006, 0.21787529742212336]
# found node: 40
# normalized distances: [0.9917698617648333, 0.006197690085861883, 0.00203244814930491]
# closest nodes:['41', '35', '43']
# normalized distances: [0.9917698617648333, 0.006197690085861883, 0.00203244814930491]
# found node: 41
# normalized distances: [0.6543294186545311, 0.17749315960284043, 0.16817742174262854]
# closest nodes:['35', '32', '43']
# normalized distances: [0.6543294186545311, 0.17749315960284043, 0.16817742174262854]
# found node: 35
# normalized distances: [0.48222387541620954, 0.34601022636909584, 0.17176589821469465]
# closest nodes:['32', '33', '36']
# normalized distances: [0.48222387541620954, 0.34601022636909584, 0.17176589821469465]
# found node: 33
# normalized distances: [0.9842570520982241, 0.008746309390831025, 0.006996638510944789]
# closest nodes:['32', '34', '36']
# normalized distances: [0.9842570520982241, 0.008746309390831025, 0.006996638510944789]
# found node: 32
# normalized distances: [0.4071492873098618, 0.387870877728175, 0.20497983496196315]
# closest nodes:['36', '34', '43']
# normalized distances: [0.4071492873098618, 0.387870877728175, 0.20497983496196315]
# found node: 36
# normalized distances: [0.38175445748525666, 0.32537049503057336, 0.29287504748416987]
# closest nodes:['4', '5', '8']
# normalized distances: [0.38175445748525666, 0.32537049503057336, 0.29287504748416987]
# found node: 8
# normalized distances: [0.5308094717752011, 0.4010870488585818, 0.06810347936621709]
# closest nodes:['6', '7', '4']
# normalized distances: [0.5308094717752011, 0.4010870488585818, 0.06810347936621709]
# found node: 7
# normalized distances: [0.9921138517568464, 0.005836326235391689, 0.0020498220077620794]
# closest nodes:['6', '28', '4']
# normalized distances: [0.9921138517568464, 0.005836326235391689, 0.0020498220077620794]
# found node: 6
# normalized distances: [0.5335527435233739, 0.2334900172185194, 0.23295723925810669]
# closest nodes:['28', '4', '5']
# normalized distances: [0.5335527435233739, 0.2334900172185194, 0.23295723925810669]
# found node: 28
# normalized distances: [0.7019627090786221, 0.15863507570708332, 0.1394022152142945]
# closest nodes:['30', '34', '4']
# normalized distances: [0.7019627090786221, 0.15863507570708332, 0.1394022152142945]
# found node: 30
# normalized distances: [0.63294151686939, 0.18601381467564865, 0.18104466845496126]
# closest nodes:['34', '4', '5']
# normalized distances: [0.63294151686939, 0.18601381467564865, 0.18104466845496126]
# found node: 4
# normalized distances: [0.9966497865604216, 0.0019735999510050893, 0.001376613488573353]
# closest nodes:['5', '37', '43']
# normalized distances: [0.9966497865604216, 0.0019735999510050893, 0.001376613488573353]
# found node: 5
# normalized distances: [0.437691184475298, 0.3048431460600104, 0.2574656694646916]
# closest nodes:['37', '43', '39']
# normalized distances: [0.437691184475298, 0.3048431460600104, 0.2574656694646916]
# found node: 43
# normalized distances: [0.4521427032053978, 0.3217511947862763, 0.2261061020083259]
# closest nodes:['37', '39', '38']
# normalized distances: [0.4521427032053978, 0.3217511947862763, 0.2261061020083259]
# found node: 38
# normalized distances: [0.9668369338365893, 0.029741746228653346, 0.003421319934757492]
# closest nodes:['39', '37', '17']
# normalized distances: [0.9668369338365893, 0.029741746228653346, 0.003421319934757492]
# found node: 39
# normalized distances: [0.8888149554701413, 0.075369232857582, 0.03581581167227671]
# closest nodes:['37', '17', '11']
# normalized distances: [0.8888149554701413, 0.075369232857582, 0.03581581167227671]
# found node: 37
# normalized distances: [0.4603352185592746, 0.28422791502458034, 0.2554368664161451]
# closest nodes:['17', '34', '18']
# normalized distances: [0.4603352185592746, 0.28422791502458034, 0.2554368664161451]
# found node: 34
# normalized distances: [0.39256523499063684, 0.3154063703102981, 0.2920283946990651]
# closest nodes:['17', '20', '11']
# normalized distances: [0.39256523499063684, 0.3154063703102981, 0.2920283946990651]
# found node: 17
# normalized distances: [0.5029938078089501, 0.34603191470969, 0.15097427748135991]
# closest nodes:['11', '18', '19']
# normalized distances: [0.5029938078089501, 0.34603191470969, 0.15097427748135991]
# found node: 18
# normalized distances: [0.5217769328126872, 0.41974724995099405, 0.058475817236318825]
# closest nodes:['11', '19', '12']
# normalized distances: [0.5217769328126872, 0.41974724995099405, 0.058475817236318825]
# found node: 11
# normalized distances: [0.8402959690712434, 0.08341552188155962, 0.07628850904719701]
# closest nodes:['19', '20', '26']
# normalized distances: [0.8402959690712434, 0.08341552188155962, 0.07628850904719701]
# found node: 19
# normalized distances: [0.4746222274415471, 0.26516167498827187, 0.2602160975701811]
# closest nodes:['12', '13', '15']
# normalized distances: [0.4746222274415471, 0.26516167498827187, 0.2602160975701811]
# found node: 13
# normalized distances: [0.5537309011268946, 0.44301165601020104, 0.003257442862904444]
# closest nodes:['15', '14', '12']
# normalized distances: [0.5537309011268946, 0.44301165601020104, 0.003257442862904444]
# found node: 15
# normalized distances: [0.9933355948294953, 0.006433540747100097, 0.00023086442340458394]
# closest nodes:['14', '12', '20']
# normalized distances: [0.9933355948294953, 0.006433540747100097, 0.00023086442340458394]
# found node: 14
# normalized distances: [0.9335105809123264, 0.033289940724892164, 0.03319947836278138]
# closest nodes:['12', '26', '20']
# normalized distances: [0.9335105809123264, 0.033289940724892164, 0.03319947836278138]
# found node: 12
# normalized distances: [0.4029687887185, 0.3742754647224378, 0.2227557465590623]
# closest nodes:['26', '20', '27']
# normalized distances: [0.4029687887185, 0.3742754647224378, 0.2227557465590623]
# found node: 26
# normalized distances: [0.6210630019325035, 0.1990717567093024, 0.17986524135819393]
# closest nodes:['20', '27', '23']
# normalized distances: [0.6210630019325035, 0.1990717567093024, 0.17986524135819393]
# found node: 23
# normalized distances: [0.6663208923333033, 0.33326109101613854, 0.0004180166505581204]
# closest nodes:['24', '27', '20']
# normalized distances: [0.6663208923333033, 0.33326109101613854, 0.0004180166505581204]
# found node: 27
# normalized distances: [0.9964376696267259, 0.003339137196732823, 0.0002231931765413726]
# closest nodes:['24', '20', '29']
# normalized distances: [0.9964376696267259, 0.003339137196732823, 0.0002231931765413726]
# found node: 24
# normalized distances: [0.9316190065990984, 0.06838099340090162]
# closest nodes:['20', '29']
# normalized distances: [0.9316190065990984, 0.06838099340090162]
# found node: 20
# normalized distances: [1.0]
# closest nodes:['29']
# normalized distances: [1.0]
# found node: 29
# Solution ['3', '2', '16', '10', '1', '25', '22', '21', '9', '45', '44', '31', '42', '40', '41', '35', '33', '32', '36', '8', '7', '6', '28', '30', '4', '5', '43', '38', '39', '37', '34', '17', '18', '11', '19', '13', '15', '14', '12', '26', '23', '27', '24', '20', '29'] takes a total of 708.692
# normalized distances: [0.49812843613193936, 0.49812843613193936, 0.0031725660397138836, 0.0005705616964074554]
# closest nodes:['13', '15', '12', '18']
# normalized distances: [0.49812843613193936, 0.49812843613193936, 0.0031725660397138836, 0.0005705616964074554]
# found node: 13
# normalized distances: [0.9923738513224809, 0.0058378557395745165, 0.0009681467004449902, 0.0008201462374996096]
# closest nodes:['15', '12', '18', '19']
# normalized distances: [0.9923738513224809, 0.0058378557395745165, 0.0009681467004449902, 0.0008201462374996096]
# found node: 15
# normalized distances: [0.6848612329912998, 0.12857333621595834, 0.10719425815712476, 0.07937117263561715]
# closest nodes:['12', '18', '19', '11']
# normalized distances: [0.6848612329912998, 0.12857333621595834, 0.10719425815712476, 0.07937117263561715]
# found node: 12
# normalized distances: [0.34166594028187797, 0.3185698715344095, 0.19719089077178067, 0.1425732974119319]
# closest nodes:['19', '18', '11', '17']
# normalized distances: [0.34166594028187797, 0.3185698715344095, 0.19719089077178067, 0.1425732974119319]
# found node: 19
# normalized distances: [0.42292350196692546, 0.4058671328605721, 0.10074861068814234, 0.0704607544843601]
# closest nodes:['18', '11', '17', '3']
# normalized distances: [0.42292350196692546, 0.4058671328605721, 0.10074861068814234, 0.0704607544843601]
# found node: 11
# normalized distances: [0.4463223304284758, 0.28496303333078926, 0.14712430310013094, 0.12159033314060406]
# closest nodes:['18', '17', '3', '2']
# normalized distances: [0.4463223304284758, 0.28496303333078926, 0.14712430310013094, 0.12159033314060406]
# found node: 3
# normalized distances: [0.4190727699961305, 0.3362714615224244, 0.13825737635911545, 0.1063983921223296]
# closest nodes:['2', '17', '16', '10']
# normalized distances: [0.4190727699961305, 0.3362714615224244, 0.13825737635911545, 0.1063983921223296]
# found node: 2
# normalized distances: [0.45364886911962155, 0.27913736046151144, 0.13381326318070585, 0.1334005072381612]
# closest nodes:['16', '10', '25', '1']
# normalized distances: [0.45364886911962155, 0.27913736046151144, 0.13381326318070585, 0.1334005072381612]
# found node: 10
# normalized distances: [0.7352681612382048, 0.12710064752429281, 0.12672335453009156, 0.010907836707410891]
# closest nodes:['16', '25', '1', '17']
# normalized distances: [0.7352681612382048, 0.12710064752429281, 0.12672335453009156, 0.010907836707410891]
# found node: 1
# normalized distances: [0.9999853323702914, 1.2503592739636015e-05, 1.1763370824180803e-06, 9.87699886592899e-07]
# closest nodes:['25', '16', '17', '22']
# normalized distances: [0.9999853323702914, 1.2503592739636015e-05, 1.1763370824180803e-06, 9.87699886592899e-07]
# found node: 25
# normalized distances: [0.8017739143174059, 0.07522095351283895, 0.06290901753609746, 0.060096114633657785]
# closest nodes:['16', '17', '22', '21']
# normalized distances: [0.8017739143174059, 0.07522095351283895, 0.06290901753609746, 0.060096114633657785]
# found node: 16
# normalized distances: [0.5101944409882453, 0.20312506641898534, 0.19507398527722222, 0.09160650731554706]
# closest nodes:['17', '22', '21', '38']
# normalized distances: [0.5101944409882453, 0.20312506641898534, 0.19507398527722222, 0.09160650731554706]
# found node: 17
# normalized distances: [0.4093214600654511, 0.22927301529448244, 0.22739224599325833, 0.13401327864680807]
# closest nodes:['18', '22', '21', '38']
# normalized distances: [0.4093214600654511, 0.22927301529448244, 0.22739224599325833, 0.13401327864680807]
# found node: 18
# normalized distances: [0.3003688123792346, 0.29856019214403823, 0.2081012308775805, 0.19296976459914658]
# closest nodes:['21', '22', '38', '39']
# normalized distances: [0.3003688123792346, 0.29856019214403823, 0.2081012308775805, 0.19296976459914658]
# found node: 38
# normalized distances: [0.9404360745280342, 0.028929605493961327, 0.025411436865780457, 0.005222883112224229]
# closest nodes:['39', '37', '43', '40']
# normalized distances: [0.9404360745280342, 0.028929605493961327, 0.025411436865780457, 0.005222883112224229]
# found node: 39
# normalized distances: [0.43408120436543834, 0.4258917367486855, 0.07188438100608648, 0.06814267787978971]
# closest nodes:['43', '37', '40', '41']
# normalized distances: [0.43408120436543834, 0.4258917367486855, 0.07188438100608648, 0.06814267787978971]
# found node: 37
# normalized distances: [0.6202011010473629, 0.15401048080555096, 0.1441180194345118, 0.08167039871257435]
# closest nodes:['43', '40', '41', '35']
# normalized distances: [0.6202011010473629, 0.15401048080555096, 0.1441180194345118, 0.08167039871257435]
# found node: 43
# normalized distances: [0.3380935415497972, 0.30955008229556846, 0.18330984788036178, 0.1690465282742725]
# closest nodes:['40', '41', '42', '31']
# normalized distances: [0.3380935415497972, 0.30955008229556846, 0.18330984788036178, 0.1690465282742725]
# found node: 40
# normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# closest nodes:['41', '35', '42', '31']
# normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# found node: 41
# normalized distances: [0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421]
# closest nodes:['35', '42', '31', '32']
# normalized distances: [0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421]
# found node: 35
# normalized distances: [0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381]
# closest nodes:['32', '33', '42', '31']
# normalized distances: [0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381]
# found node: 32
# normalized distances: [0.9605818473057438, 0.016557767787301763, 0.01536560225402276, 0.007494782652931541]
# closest nodes:['33', '42', '31', '36']
# normalized distances: [0.9605818473057438, 0.016557767787301763, 0.01536560225402276, 0.007494782652931541]
# found node: 33
# normalized distances: [0.33456954885998164, 0.3174721608585357, 0.1933151834646641, 0.15464310681681862]
# closest nodes:['42', '31', '34', '36']
# normalized distances: [0.33456954885998164, 0.3174721608585357, 0.1933151834646641, 0.15464310681681862]
# found node: 42
# normalized distances: [0.991892770577667, 0.003252200254848149, 0.003099506823521251, 0.001755522343963593]
# closest nodes:['31', '44', '45', '34']
# normalized distances: [0.991892770577667, 0.003252200254848149, 0.003099506823521251, 0.001755522343963593]
# found node: 31
# normalized distances: [0.3380278724083087, 0.32362907893637344, 0.17816925659964103, 0.16017379205567686]
# closest nodes:['44', '45', '34', '36']
# normalized distances: [0.3380278724083087, 0.32362907893637344, 0.17816925659964103, 0.16017379205567686]
# found node: 44
# normalized distances: [0.9956269540677302, 0.0021785247588756752, 0.0011146332609162596, 0.0010798879124781723]
# closest nodes:['45', '9', '22', '21']
# normalized distances: [0.9956269540677302, 0.0021785247588756752, 0.0011146332609162596, 0.0010798879124781723]
# found node: 45
# normalized distances: [0.44119550692710197, 0.21763818709763808, 0.21097830881084512, 0.1301879971644148]
# closest nodes:['9', '22', '21', '20']
# normalized distances: [0.44119550692710197, 0.21763818709763808, 0.21097830881084512, 0.1301879971644148]
# found node: 20
# normalized distances: [0.2778227242420629, 0.2664515431812182, 0.25570030836497326, 0.20002542421174568]
# closest nodes:['26', '21', '22', '9']
# normalized distances: [0.2778227242420629, 0.2664515431812182, 0.25570030836497326, 0.20002542421174568]
# found node: 9
# normalized distances: [0.4457161006426711, 0.4308908280415356, 0.0908509920948989, 0.03254207922089436]
# closest nodes:['22', '21', '26', '27']
# normalized distances: [0.4457161006426711, 0.4308908280415356, 0.0908509920948989, 0.03254207922089436]
# found node: 22
# normalized distances: [0.9994865630164123, 0.000341695572626059, 8.803797645724628e-05, 8.37034345044645e-05]
# closest nodes:['21', '26', '27', '23']
# normalized distances: [0.9994865630164123, 0.000341695572626059, 8.803797645724628e-05, 8.37034345044645e-05]
# found node: 21
# normalized distances: [0.5793877031025002, 0.14651290946089368, 0.1392317954858113, 0.13486759195079487]
# closest nodes:['26', '27', '23', '24']
# normalized distances: [0.5793877031025002, 0.14651290946089368, 0.1392317954858113, 0.13486759195079487]
# found node: 27
# normalized distances: [0.712858200338234, 0.28507449939425583, 0.0019523758462243578, 0.0001149244212857787]
# closest nodes:['23', '24', '26', '4']
# normalized distances: [0.712858200338234, 0.28507449939425583, 0.0019523758462243578, 0.0001149244212857787]
# found node: 23
# normalized distances: [0.9986075030113425, 0.0012359300113308318, 7.86057856141526e-05, 7.796119171229478e-05]
# closest nodes:['24', '26', '4', '5']
# normalized distances: [0.9986075030113425, 0.0012359300113308318, 7.86057856141526e-05, 7.796119171229478e-05]
# found node: 24
# normalized distances: [0.8366944071894912, 0.0553037225367088, 0.0548575841629514, 0.05314428611084863]
# closest nodes:['26', '4', '5', '36']
# normalized distances: [0.8366944071894912, 0.0553037225367088, 0.0548575841629514, 0.05314428611084863]
# found node: 4
# normalized distances: [0.9833997443256275, 0.010659463642896248, 0.0037108606384476917, 0.0022299313930286336]
# closest nodes:['5', '36', '8', '6']
# normalized distances: [0.9833997443256275, 0.010659463642896248, 0.0037108606384476917, 0.0022299313930286336]
# found node: 5
# normalized distances: [0.5358945043669977, 0.2132717527373383, 0.13123488488469934, 0.11959885801096468]
# closest nodes:['36', '8', '6', '7']
# normalized distances: [0.5358945043669977, 0.2132717527373383, 0.13123488488469934, 0.11959885801096468]
# found node: 36
# normalized distances: [0.5056793723590726, 0.216199061054275, 0.19473744497781814, 0.08338412160883432]
# closest nodes:['8', '6', '7', '28']
# normalized distances: [0.5056793723590726, 0.216199061054275, 0.19473744497781814, 0.08338412160883432]
# found node: 8
# normalized distances: [0.5217223343793871, 0.39422068095359636, 0.058161830477708946, 0.025895154189307705]
# closest nodes:['6', '7', '28', '30']
# normalized distances: [0.5217223343793871, 0.39422068095359636, 0.058161830477708946, 0.025895154189307705]
# found node: 7
# normalized distances: [0.9917153943316162, 0.005833982222635049, 0.0015791555881711767, 0.0008714678575776381]
# closest nodes:['6', '28', '30', '34']
# normalized distances: [0.9917153943316162, 0.005833982222635049, 0.0015791555881711767, 0.0008714678575776381]
# found node: 6
# normalized distances: [0.6735390964129004, 0.1990556817156228, 0.11554212375951793, 0.011863098111958886]
# closest nodes:['28', '30', '34', '26']
# normalized distances: [0.6735390964129004, 0.1990556817156228, 0.11554212375951793, 0.011863098111958886]
# found node: 28
# normalized distances: [0.7919756199119725, 0.17897690404067956, 0.015332673846140937, 0.013714802201207101]
# closest nodes:['30', '34', '29', '26']
# normalized distances: [0.7919756199119725, 0.17897690404067956, 0.015332673846140937, 0.013714802201207101]
# found node: 30
# normalized distances: [0.914338345763578, 0.05092873722227581, 0.03473291701414628]
# closest nodes:['34', '29', '26']
# normalized distances: [0.914338345763578, 0.05092873722227581, 0.03473291701414628]
# found node: 34
# normalized distances: [0.5469489855904897, 0.4530510144095103]
# closest nodes:['29', '26']
# normalized distances: [0.5469489855904897, 0.4530510144095103]
# found node: 26
# normalized distances: [1.0]
# closest nodes:['29']
# normalized distances: [1.0]
# found node: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  521.439
# Improvement over randomized greedy heuristic:  0.319

# %% [markdown]
# **(TO DO) Q6 - 2 points**
# Tester le recuit simulé en variant certains paramètres, tel en faisant un changement sur les températures à explorer (T, stopping_T, alpha), ou encore sur le nombre d'itérations maximales à faire.  Ces paramètres sont tous des paramètres possibles à assigner à l'instantiation de la classe SimAnneal. Explorer 4 variations ci-bas.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, stopping_iter=100) means that I set a maximum of 100 iterations.
# Try a few variations and look at the differences

# Test 1 ... (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, T=-1, alpha=-1, stopping_T=-1, stopping_iter=50)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 ... (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, T=-1, alpha=-1, stopping_T=-1, stopping_iter=20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 ... (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False, T=1, alpha=1, stopping_T=-1, stopping_iter=200)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, T=-1, alpha=-1, stopping_T=-1, stopping_iter=48)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# 1e-08
# Best fitness obtained:  532.255
# Improvement over greedy heuristic:  0.1024
# normalized distances: [0.3649475478003521, 0.2817445329775328, 0.23300774605649544, 0.12030017316561958]
# closest nodes:['18', '19', '17', '3']
# normalized distances: [0.3649475478003521, 0.2817445329775328, 0.23300774605649544, 0.12030017316561958]
# found node: 19
# normalized distances: [0.6434031536805791, 0.15327115552627069, 0.10719355021678523, 0.09613214057636493]
# closest nodes:['18', '17', '3', '12']
# normalized distances: [0.6434031536805791, 0.15327115552627069, 0.10719355021678523, 0.09613214057636493]
# found node: 18
# normalized distances: [0.3949412944597345, 0.26350786659076286, 0.18543724354460617, 0.15611359540489644]
# closest nodes:['17', '3', '2', '16']
# normalized distances: [0.3949412944597345, 0.26350786659076286, 0.18543724354460617, 0.15611359540489644]
# found node: 17
# normalized distances: [0.4888004709492067, 0.24142911342538773, 0.15228988389967577, 0.11748053172572977]
# closest nodes:['3', '2', '16', '10']
# normalized distances: [0.4888004709492067, 0.24142911342538773, 0.15228988389967577, 0.11748053172572977]
# found node: 10
# normalized distances: [0.7031675566501439, 0.12155164126487171, 0.12119082026532384, 0.05408998181966063]
# closest nodes:['16', '25', '1', '2']
# normalized distances: [0.7031675566501439, 0.12155164126487171, 0.12119082026532384, 0.05408998181966063]
# found node: 16
# normalized distances: [0.3386872489916783, 0.3370126545282907, 0.2695760389177324, 0.054724057562298686]
# closest nodes:['25', '1', '2', '3']
# normalized distances: [0.3386872489916783, 0.3370126545282907, 0.2695760389177324, 0.054724057562298686]
# found node: 1
# normalized distances: [0.9999949251078667, 2.9411130160701367e-06, 1.146069755715329e-06, 9.877093614776885e-07]
# closest nodes:['25', '2', '3', '22']
# normalized distances: [0.9999949251078667, 2.9411130160701367e-06, 1.146069755715329e-06, 9.877093614776885e-07]
# found node: 25
# normalized distances: [0.48953640475879845, 0.190578110740926, 0.1636003408882066, 0.15628514361206894]
# closest nodes:['2', '3', '22', '21']
# normalized distances: [0.48953640475879845, 0.190578110740926, 0.1636003408882066, 0.15628514361206894]
# found node: 22
# normalized distances: [0.996925118315517, 0.0011065139795861509, 0.000988080125409212, 0.000980287579487694]
# closest nodes:['21', '9', '2', '20']
# normalized distances: [0.996925118315517, 0.0011065139795861509, 0.000988080125409212, 0.000980287579487694]
# found node: 21
# normalized distances: [0.28870653169902477, 0.27569650786595434, 0.2586984803462105, 0.17689848008881037]
# closest nodes:['9', '20', '2', '3']
# normalized distances: [0.28870653169902477, 0.27569650786595434, 0.2586984803462105, 0.17689848008881037]
# found node: 9
# normalized distances: [0.34731467020408363, 0.2508499638098397, 0.24699267925303112, 0.15484268673304558]
# closest nodes:['20', '45', '44', '2']
# normalized distances: [0.34731467020408363, 0.2508499638098397, 0.24699267925303112, 0.15484268673304558]
# found node: 45
# normalized distances: [0.9904104451417141, 0.0032473400327519973, 0.0032473400327519973, 0.003094874792781941]
# closest nodes:['44', '31', '43', '42']
# normalized distances: [0.9904104451417141, 0.0032473400327519973, 0.0032473400327519973, 0.003094874792781941]
# found node: 44
# normalized distances: [0.28600362789087136, 0.2664009220492972, 0.25505318368088364, 0.1925422663789479]
# closest nodes:['43', '31', '42', '39']
# normalized distances: [0.28600362789087136, 0.2664009220492972, 0.25505318368088364, 0.1925422663789479]
# found node: 42
# normalized distances: [0.9619366446214602, 0.014970318915273562, 0.014799971589282852, 0.008293064873983324]
# closest nodes:['31', '41', '40', '32']
# normalized distances: [0.9619366446214602, 0.014970318915273562, 0.014799971589282852, 0.008293064873983324]
# found node: 31
# normalized distances: [0.30920760233976863, 0.30641382861531136, 0.20100259463776146, 0.18337597440715858]
# closest nodes:['41', '40', '32', '33']
# normalized distances: [0.30920760233976863, 0.30641382861531136, 0.20100259463776146, 0.18337597440715858]
# found node: 33
# normalized distances: [0.9541389691672564, 0.0224413309554954, 0.012131524502117217, 0.01128817537513098]
# closest nodes:['32', '35', '41', '40']
# normalized distances: [0.9541389691672564, 0.0224413309554954, 0.012131524502117217, 0.01128817537513098]
# found node: 32
# normalized distances: [0.46159988638443783, 0.22302025084001373, 0.2055061981668006, 0.10987366460874777]
# closest nodes:['35', '41', '40', '36']
# normalized distances: [0.46159988638443783, 0.22302025084001373, 0.2055061981668006, 0.10987366460874777]
# found node: 35
# normalized distances: [0.4591614139226044, 0.393054669229584, 0.0918248415354819, 0.055959075312329784]
# closest nodes:['41', '40', '36', '37']
# normalized distances: [0.4591614139226044, 0.393054669229584, 0.0918248415354819, 0.055959075312329784]
# found node: 41
# normalized distances: [0.995816567828629, 0.0018684520837686748, 0.00156339772449038, 0.0007515823631118142]
# closest nodes:['40', '43', '37', '39']
# normalized distances: [0.995816567828629, 0.0018684520837686748, 0.00156339772449038, 0.0007515823631118142]
# found node: 40
# normalized distances: [0.39236185167266324, 0.3212183350374564, 0.15243713604367995, 0.1339826772462004]
# closest nodes:['43', '37', '39', '36']
# normalized distances: [0.39236185167266324, 0.3212183350374564, 0.15243713604367995, 0.1339826772462004]
# found node: 43
# normalized distances: [0.44119149588193607, 0.3139581594996373, 0.22062965666786422, 0.024220687950562352]
# closest nodes:['37', '39', '38', '2']
# normalized distances: [0.44119149588193607, 0.3139581594996373, 0.22062965666786422, 0.024220687950562352]
# found node: 37
# normalized distances: [0.4949622729982565, 0.4035982443626827, 0.051945915371934395, 0.04949356726712649]
# closest nodes:['39', '38', '4', '5']
# normalized distances: [0.4949622729982565, 0.4035982443626827, 0.051945915371934395, 0.04949356726712649]
# found node: 38
# normalized distances: [0.9865749516258309, 0.006013731621097744, 0.005214760306744077, 0.0021965564463273753]
# closest nodes:['39', '2', '3', '4']
# normalized distances: [0.9865749516258309, 0.006013731621097744, 0.005214760306744077, 0.0021965564463273753]
# found node: 39
# normalized distances: [0.3707992347711329, 0.3196152942518929, 0.15732448420287337, 0.15226098677410074]
# closest nodes:['2', '3', '4', '5']
# normalized distances: [0.3707992347711329, 0.3196152942518929, 0.15732448420287337, 0.15226098677410074]
# found node: 2
# normalized distances: [0.967189292730422, 0.01571559905149521, 0.009713294676449097, 0.007381813541633797]
# closest nodes:['3', '20', '26', '12']
# normalized distances: [0.967189292730422, 0.01571559905149521, 0.009713294676449097, 0.007381813541633797]
# found node: 3
# normalized distances: [0.33776358936537376, 0.22821956064692153, 0.22606359817086627, 0.20795325181683844]
# closest nodes:['20', '26', '12', '15']
# normalized distances: [0.33776358936537376, 0.22821956064692153, 0.22606359817086627, 0.20795325181683844]
# found node: 26
# normalized distances: [0.5306533246026176, 0.17009238870061594, 0.1536818132946049, 0.14557247340216156]
# closest nodes:['20', '27', '23', '24']
# normalized distances: [0.5306533246026176, 0.17009238870061594, 0.1536818132946049, 0.14557247340216156]
# found node: 20
# normalized distances: [0.31540879810720984, 0.2952184027479368, 0.28195861444290415, 0.10741418470194922]
# closest nodes:['27', '23', '24', '12']
# normalized distances: [0.31540879810720984, 0.2952184027479368, 0.28195861444290415, 0.10741418470194922]
# found node: 24
# normalized distances: [0.8331624056971879, 0.16664261301030858, 0.00010891081177638754, 8.607048072711853e-05]
# closest nodes:['23', '27', '12', '13']
# normalized distances: [0.8331624056971879, 0.16664261301030858, 0.00010891081177638754, 8.607048072711853e-05]
# found node: 23
# normalized distances: [0.9993218910967043, 0.00026341936121751123, 0.0002082804690787425, 0.00020640907299933217]
# closest nodes:['27', '12', '13', '15']
# normalized distances: [0.9993218910967043, 0.00026341936121751123, 0.0002082804690787425, 0.00020640907299933217]
# found node: 27
# normalized distances: [0.2993057485136725, 0.23606518799470466, 0.23393427647179732, 0.2306947870198256]
# closest nodes:['12', '13', '15', '14']
# normalized distances: [0.2993057485136725, 0.23606518799470466, 0.23393427647179732, 0.2306947870198256]
# found node: 14
# normalized distances: [0.4983436394591118, 0.4983436394591118, 0.003173936663669268, 0.0001387844181071976]
# closest nodes:['13', '15', '12', '5']
# normalized distances: [0.4983436394591118, 0.4983436394591118, 0.003173936663669268, 0.0001387844181071976]
# found node: 13
# normalized distances: [0.993713518738136, 0.00584573662549385, 0.00022210829447430615, 0.00021863634189592766]
# closest nodes:['15', '12', '5', '4']
# normalized distances: [0.993713518738136, 0.00584573662549385, 0.00022210829447430615, 0.00021863634189592766]
# found node: 15
# normalized distances: [0.8917099001973046, 0.03946074805124099, 0.03882906039624647, 0.030000291355207917]
# closest nodes:['12', '5', '4', '36']
# normalized distances: [0.8917099001973046, 0.03946074805124099, 0.03882906039624647, 0.030000291355207917]
# found node: 12
# normalized distances: [0.28958728697144887, 0.28656326462266085, 0.23002800027260364, 0.19382144813328656]
# closest nodes:['5', '4', '36', '8']
# normalized distances: [0.28958728697144887, 0.28656326462266085, 0.23002800027260364, 0.19382144813328656]
# found node: 8
# normalized distances: [0.46154059170684986, 0.34874651583938177, 0.13049669184819435, 0.05921620060557399]
# closest nodes:['6', '7', '36', '4']
# normalized distances: [0.46154059170684986, 0.34874651583938177, 0.13049669184819435, 0.05921620060557399]
# found node: 36
# normalized distances: [0.40391841488398733, 0.34426090390272135, 0.13248614818394744, 0.11933453302934394]
# closest nodes:['4', '5', '6', '7']
# normalized distances: [0.40391841488398733, 0.34426090390272135, 0.13248614818394744, 0.11933453302934394]
# found node: 5
# normalized distances: [0.9948353152815632, 0.002250714961877941, 0.0020511538481958742, 0.0008628159083631376]
# closest nodes:['4', '6', '7', '28']
# normalized distances: [0.9948353152815632, 0.002250714961877941, 0.0020511538481958742, 0.0008628159083631376]
# found node: 4
# normalized distances: [0.3796069299719743, 0.34588152090421626, 0.14710825382457784, 0.1274032952992316]
# closest nodes:['6', '7', '28', '34']
# normalized distances: [0.3796069299719743, 0.34588152090421626, 0.14710825382457784, 0.1274032952992316]
# found node: 6
# normalized distances: [0.9924554079502341, 0.005142584698834606, 0.0015198237317753526, 0.0008821836191559359]
# closest nodes:['7', '28', '30', '34']
# normalized distances: [0.9924554079502341, 0.005142584698834606, 0.0015198237317753526, 0.0008821836191559359]
# found node: 7
# normalized distances: [0.6979701202103864, 0.18892814095839064, 0.10426129221871684, 0.008840446612506155]
# closest nodes:['28', '30', '34', '29']
# normalized distances: [0.6979701202103864, 0.18892814095839064, 0.10426129221871684, 0.008840446612506155]
# found node: 28
# normalized distances: [0.8029884476412262, 0.18146566980841147, 0.015545882550362353]
# closest nodes:['30', '34', '29']
# normalized distances: [0.8029884476412262, 0.18146566980841147, 0.015545882550362353]
# found node: 30
# normalized distances: [0.9472387092443489, 0.052761290755651086]
# closest nodes:['34', '29']
# normalized distances: [0.9472387092443489, 0.052761290755651086]
# found node: 34
# normalized distances: [1.0]
# closest nodes:['29']
# normalized distances: [1.0]
# found node: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  674.189
# Improvement over randomized greedy heuristic:  0.0
# 1
# 1e-08
# Best fitness obtained:  582.829
# Improvement over greedy heuristic:  0.0242
# normalized distances: [0.4190727699961305, 0.3362714615224244, 0.13825737635911545, 0.1063983921223296]
# closest nodes:['2', '17', '16', '10']
# normalized distances: [0.4190727699961305, 0.3362714615224244, 0.13825737635911545, 0.1063983921223296]
# found node: 2
# normalized distances: [0.45364886911962155, 0.27913736046151144, 0.13381326318070585, 0.1334005072381612]
# closest nodes:['16', '10', '25', '1']
# normalized distances: [0.45364886911962155, 0.27913736046151144, 0.13381326318070585, 0.1334005072381612]
# found node: 10
# normalized distances: [0.7352681612382048, 0.12710064752429281, 0.12672335453009156, 0.010907836707410891]
# closest nodes:['16', '25', '1', '17']
# normalized distances: [0.7352681612382048, 0.12710064752429281, 0.12672335453009156, 0.010907836707410891]
# found node: 25
# normalized distances: [0.999985269450333, 1.2565721506716701e-05, 1.1788928729574882e-06, 9.85935287371817e-07]
# closest nodes:['1', '16', '17', '22']
# normalized distances: [0.999985269450333, 1.2565721506716701e-05, 1.1788928729574882e-06, 9.85935287371817e-07]
# found node: 1
# normalized distances: [0.800950441062506, 0.0753533584002809, 0.06326970785734332, 0.06042649267986973]
# closest nodes:['16', '17', '22', '21']
# normalized distances: [0.800950441062506, 0.0753533584002809, 0.06326970785734332, 0.06042649267986973]
# found node: 16
# normalized distances: [0.5033564318417453, 0.20040263169514552, 0.19245945719066357, 0.10378147927244552]
# closest nodes:['17', '22', '21', '11']
# normalized distances: [0.5033564318417453, 0.20040263169514552, 0.19245945719066357, 0.10378147927244552]
# found node: 11
# normalized distances: [0.38785730240977684, 0.29943117905028116, 0.2476349173210349, 0.06507660121890706]
# closest nodes:['18', '19', '17', '21']
# normalized distances: [0.38785730240977684, 0.29943117905028116, 0.2476349173210349, 0.06507660121890706]
# found node: 21
# normalized distances: [0.9971596516440332, 0.0010699611063959167, 0.0010217452956459855, 0.0007486419539247948]
# closest nodes:['22', '9', '20', '17']
# normalized distances: [0.9971596516440332, 0.0010699611063959167, 0.0010217452956459855, 0.0007486419539247948]
# found node: 22
# normalized distances: [0.3477112972721126, 0.30804587402582095, 0.23714348081887734, 0.10709934788318916]
# closest nodes:['9', '20', '17', '26']
# normalized distances: [0.3477112972721126, 0.30804587402582095, 0.23714348081887734, 0.10709934788318916]
# found node: 26
# normalized distances: [0.5306533246026176, 0.17009238870061594, 0.1536818132946049, 0.14557247340216156]
# closest nodes:['20', '27', '23', '24']
# normalized distances: [0.5306533246026176, 0.17009238870061594, 0.1536818132946049, 0.14557247340216156]
# found node: 20
# normalized distances: [0.5763739230962343, 0.17523069085080015, 0.12555671666138243, 0.12283866939158299]
# closest nodes:['9', '17', '27', '45']
# normalized distances: [0.5763739230962343, 0.17523069085080015, 0.12555671666138243, 0.12283866939158299]
# found node: 9
# normalized distances: [0.3402455570407368, 0.33501364903978176, 0.16340674819338669, 0.16133404572609492]
# closest nodes:['45', '44', '39', '38']
# normalized distances: [0.3402455570407368, 0.33501364903978176, 0.16340674819338669, 0.16133404572609492]
# found node: 45
# normalized distances: [0.9904104451417141, 0.0032473400327519973, 0.0032473400327519973, 0.003094874792781941]
# closest nodes:['44', '31', '43', '42']
# normalized distances: [0.9904104451417141, 0.0032473400327519973, 0.0032473400327519973, 0.003094874792781941]
# found node: 44
# normalized distances: [0.28600362789087136, 0.2664009220492972, 0.25505318368088364, 0.1925422663789479]
# closest nodes:['43', '31', '42', '39']
# normalized distances: [0.28600362789087136, 0.2664009220492972, 0.25505318368088364, 0.1925422663789479]
# found node: 43
# normalized distances: [0.39761220937566466, 0.28294651781677554, 0.19883666403438396, 0.12060460877317578]
# closest nodes:['37', '39', '38', '40']
# normalized distances: [0.39761220937566466, 0.28294651781677554, 0.19883666403438396, 0.12060460877317578]
# found node: 40
# normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# closest nodes:['41', '35', '42', '31']
# normalized distances: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# found node: 41
# normalized distances: [0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421]
# closest nodes:['35', '42', '31', '32']
# normalized distances: [0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421]
# found node: 35
# normalized distances: [0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381]
# closest nodes:['32', '33', '42', '31']
# normalized distances: [0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381]
# found node: 33
# normalized distances: [0.9625946372334128, 0.014804037734449792, 0.014047512288555542, 0.008553812743581938]
# closest nodes:['32', '42', '31', '34']
# normalized distances: [0.9625946372334128, 0.014804037734449792, 0.014047512288555542, 0.008553812743581938]
# found node: 32
# normalized distances: [0.35563698318443526, 0.3300309860984658, 0.16097712726444546, 0.15335490345265365]
# closest nodes:['42', '31', '36', '34']
# normalized distances: [0.35563698318443526, 0.3300309860984658, 0.16097712726444546, 0.15335490345265365]
# found node: 31
# normalized distances: [0.9936597228666352, 0.0026358346316124573, 0.0019108017121835675, 0.0017936407895687357]
# closest nodes:['42', '37', '39', '34']
# normalized distances: [0.9936597228666352, 0.0026358346316124573, 0.0019108017121835675, 0.0017936407895687357]
# found node: 42
# normalized distances: [0.3406763727040975, 0.23908490807851887, 0.21161857726584493, 0.2086201419515387]
# closest nodes:['37', '39', '38', '34']
# normalized distances: [0.3406763727040975, 0.23908490807851887, 0.21161857726584493, 0.2086201419515387]
# found node: 34
# normalized distances: [0.3736929596280671, 0.24630011729023138, 0.19989763920177367, 0.1801092838799279]
# closest nodes:['30', '36', '8', '28']
# normalized distances: [0.3736929596280671, 0.24630011729023138, 0.19989763920177367, 0.1801092838799279]
# found node: 36
# normalized distances: [0.3392720587043724, 0.28916261624776607, 0.26028332703078544, 0.11128199801707608]
# closest nodes:['4', '5', '8', '6']
# normalized distances: [0.3392720587043724, 0.28916261624776607, 0.26028332703078544, 0.11128199801707608]
# found node: 8
# normalized distances: [0.49777900795008817, 0.37612876916975346, 0.0638656320195088, 0.06222659086064959]
# closest nodes:['6', '7', '4', '5']
# normalized distances: [0.49777900795008817, 0.37612876916975346, 0.0638656320195088, 0.06222659086064959]
# found node: 6
# normalized distances: [0.9903817574342032, 0.005131839708854154, 0.0022457636222997807, 0.002240639234642821]
# closest nodes:['7', '28', '4', '5']
# normalized distances: [0.9903817574342032, 0.005131839708854154, 0.0022457636222997807, 0.002240639234642821]
# found node: 7
# normalized distances: [0.5070004644932582, 0.17806761790692296, 0.17769587776350146, 0.13723603983631738]
# closest nodes:['28', '4', '5', '30']
# normalized distances: [0.5070004644932582, 0.17806761790692296, 0.17769587776350146, 0.13723603983631738]
# found node: 28
# normalized distances: [0.6768644821467029, 0.13441797832106556, 0.13266610863425762, 0.05605143089797385]
# closest nodes:['30', '4', '5', '37']
# normalized distances: [0.6768644821467029, 0.13441797832106556, 0.13266610863425762, 0.05605143089797385]
# found node: 30
# normalized distances: [0.33504663279136965, 0.32609624535916554, 0.18889027358671753, 0.14996684826274728]
# closest nodes:['4', '5', '37', '39']
# normalized distances: [0.33504663279136965, 0.32609624535916554, 0.18889027358671753, 0.14996684826274728]
# found node: 4
# normalized distances: [0.9957773511176421, 0.0019718723245405645, 0.0011419191341831853, 0.001108857423634115]
# closest nodes:['5', '37', '39', '38']
# normalized distances: [0.9957773511176421, 0.0019718723245405645, 0.0011419191341831853, 0.001108857423634115]
# found node: 5
# normalized distances: [0.42231012199811147, 0.2484179762777374, 0.24197500457449722, 0.08729689714965384]
# closest nodes:['37', '39', '38', '17']
# normalized distances: [0.42231012199811147, 0.2484179762777374, 0.24197500457449722, 0.08729689714965384]
# found node: 38
# normalized distances: [0.9653440277719789, 0.029695821593626565, 0.0034160370280947277, 0.0015441136062999158]
# closest nodes:['39', '37', '17', '18']
# normalized distances: [0.9653440277719789, 0.029695821593626565, 0.0034160370280947277, 0.0015441136062999158]
# found node: 39
# normalized distances: [0.8696187818962691, 0.07374144648072198, 0.03419043328746537, 0.022449338335543467]
# closest nodes:['37', '17', '18', '19']
# normalized distances: [0.8696187818962691, 0.07374144648072198, 0.03419043328746537, 0.022449338335543467]
# found node: 19
# normalized distances: [0.6797612017535379, 0.1619323503136196, 0.10156446860963271, 0.056741979323209644]
# closest nodes:['18', '17', '12', '13']
# normalized distances: [0.6797612017535379, 0.1619323503136196, 0.10156446860963271, 0.056741979323209644]
# found node: 18
# normalized distances: [0.6189742699049761, 0.15793216705589663, 0.11170693474861543, 0.1113866282905119]
# closest nodes:['17', '12', '13', '15']
# normalized distances: [0.6189742699049761, 0.15793216705589663, 0.11170693474861543, 0.1113866282905119]
# found node: 15
# normalized distances: [0.5537831985228963, 0.4430534964709023, 0.0028695264093299574, 0.00029377859687152943]
# closest nodes:['13', '14', '12', '17']
# normalized distances: [0.5537831985228963, 0.4430534964709023, 0.0028695264093299574, 0.00029377859687152943]
# found node: 13
# normalized distances: [0.9917240726636736, 0.007292098206992605, 0.0006530991041586962, 0.00033073002517499116]
# closest nodes:['14', '12', '17', '37']
# normalized distances: [0.9917240726636736, 0.007292098206992605, 0.0006530991041586962, 0.00033073002517499116]
# found node: 14
# normalized distances: [0.8537528667642876, 0.08469464354604865, 0.04400822837539003, 0.017544261314273706]
# closest nodes:['12', '17', '37', '27']
# normalized distances: [0.8537528667642876, 0.08469464354604865, 0.04400822837539003, 0.017544261314273706]
# found node: 12
# normalized distances: [0.5462963236372481, 0.2167999091889884, 0.1202276576748385, 0.11667610949892498]
# closest nodes:['17', '37', '27', '23']
# normalized distances: [0.5462963236372481, 0.2167999091889884, 0.1202276576748385, 0.11667610949892498]
# found node: 37
# normalized distances: [0.7332671698141641, 0.09127864520407836, 0.08859480485300769, 0.08685938012875002]
# closest nodes:['17', '27', '23', '24']
# normalized distances: [0.7332671698141641, 0.09127864520407836, 0.08859480485300769, 0.08685938012875002]
# found node: 17
# normalized distances: [0.32015100572276695, 0.30685170229745534, 0.3001484902269411, 0.07284880175283663]
# closest nodes:['27', '23', '24', '29']
# normalized distances: [0.32015100572276695, 0.30685170229745534, 0.3001484902269411, 0.07284880175283663]
# found node: 24
# normalized distances: [0.8332943489592972, 0.16666900326725806, 3.664777344468167e-05]
# closest nodes:['23', '27', '29']
# normalized distances: [0.8332943489592972, 0.16666900326725806, 3.664777344468167e-05]
# found node: 23
# normalized distances: [0.9999110070888495, 8.89929111505262e-05]
# closest nodes:['27', '29']
# normalized distances: [0.9999110070888495, 8.89929111505262e-05]
# found node: 27
# normalized distances: [1.0]
# closest nodes:['29']
# normalized distances: [1.0]
# found node: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  780.298
# Improvement over randomized greedy heuristic:  0.0019

# %% [markdown]
# #### Signature
#
# Je, Dounia Mansouri, déclare que les réponses inscrites dans ce notebook sont les miennes.
